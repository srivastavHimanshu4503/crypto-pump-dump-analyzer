# %%
import pdfplumber #type: igmore

# filename = "_7_2022.pdf"
# with pdfplumber.open(filename) as pdf:
#     content = ""
#     for page in pdf.pages:
#         text = page.extract_text()
#         content += text

# with open(f'Cases/{filename.split('.')[0]}.txt', 'w') as f:
#     f.write(content)

fn2 = 'Cases/_7_2022.txt'
with open(fn2) as f:
    data = f.readlines()

# print(data)

keyword = "Dr. Mrinmoy Barman"

for row in data:
    if keyword in row:
        print(fn2)
        break
else:
    print(f"{keyword} not found.")
# Out:
# Cases/_7_2022.txt
